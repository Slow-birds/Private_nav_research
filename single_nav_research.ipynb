# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import copy
from WindPy import w
w.start()
from function import *
from nav_research import NavResearch
import warnings
warnings.filterwarnings("ignore")

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2024 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.

# %%
fund_name = "辰元优选稳健"

# %%
basic_info = load_data(r"data\产品目录.xlsx")
indices = basic_info[basic_info["fund_name"] == fund_name].index.item()
strategy = basic_info.loc[indices,"strategy"]
fund_code = basic_info.loc[indices,"fund_code"]
benchmark_code = basic_info.loc[indices,"benchmark_code"]
benchmark_name = basic_info.loc[indices,"benchmark_name"]
threshold = basic_info.loc[indices,"threshold"]

# %%
demo = NavResearch(r"data\辰元优选稳健_20241129.xlsx",strategy,fund_code,fund_name,benchmark_code,benchmark_name,threshold)
demo.get_data()
demo.get_analysis_table()
demo.get_html()

# %%
demo.get_plot()
